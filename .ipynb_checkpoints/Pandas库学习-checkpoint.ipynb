# %% [markdown]
# # Pandas库学习

# %% [markdown]
# 结合[Pandas中文网](https://www.pypandas.cn/docs/getting_started/10min.html#%E9%80%89%E6%8B%A9) 进行学习

# %% [markdown]
# ## Series类型基本操作

# %%
import pandas as pd

# %%
b = pd.Series([9,8,7,6],['a','b','c','d'])

# %%
b
# Out:
# a    9
# b    8
# c    7
# d    6
# dtype: int64

# %% [markdown]
# ### 自动索引和自定义索引

# %%
b['b']
# Out:
# 8

# %%
b[1]
# Out:
# 8

# %% [markdown]
# 自动索引和自定义索引可以并存，但不能混用

# %% [markdown]
# ### 常用方法or属性

# %%
b.get('d',"No found")
# Out:
# 6

# %%
b.get('f',"No found")
# Out:
# 'No found'

# %%
b.name = "皮卡丘"
b.index.name = "精灵球"

# %%
b
# Out:
# 精灵球
# a    9
# b    8
# c    7
# d    6
# Name: 皮卡丘, dtype: int64

# %% [markdown]
# ## DataFrame类型基本操作

# %% [markdown]
# ### 创建

# %% [markdown]
# DataFrame类型可以由下面类型创建：
# * 二维ndarray对象
# * 列表，字典，元组，一维ndarray
# * Series类型
# * 其他

# %%
import numpy as np

# %%
d = pd.DataFrame(np.arange(10).reshape(2,5))

# %%
d
# Out:
#    0  1  2  3  4
# 0  0  1  2  3  4
# 1  5  6  7  8  9

# %%
dt = {'one': pd.Series([1,2,3],index = ['a','b','c']),
     'two': pd.Series([9,8,7,6],index = ['a','b','c','d'])}

# %%
dt
# Out:
# {'one': a    1
#  b    2
#  c    3
#  dtype: int64,
#  'two': a    9
#  b    8
#  c    7
#  d    6
#  dtype: int64}

# %%
d1 = pd.DataFrame(dt)
d1
# Out:
#    one  two
# a  1.0    9
# b  2.0    8
# c  3.0    7
# d  NaN    6

# %%
dl = {'one':[1,2,3,4],'two':[9,8,7,6]}
dl
# Out:
# {'one': [1, 2, 3, 4], 'two': [9, 8, 7, 6]}

# %%
d2 = pd.DataFrame(dl, index = ['a','b','c','d'])
d2
# Out:
#    one  two
# a    1    9
# b    2    8
# c    3    7
# d    4    6

# %% [markdown]
# ### 内容获取

# %%
# 列的获取
d2['two']
# Out:
# a    9
# b    8
# c    7
# d    6
# Name: two, dtype: int64

# %%
# 行的获取-标记索引，loc指的是location的缩写
d2.loc['c']
# Out:
# one    3
# two    7
# Name: c, dtype: int64

# %%
# 行的获取-位置索引
d2.iloc[2]
# Out:
# one    3
# two    7
# Name: c, dtype: int64

# %%
# 行列唯一,必须先列再行
d2['two']['c']
# Out:
# 7

# %% [markdown]
# ## 数据类型操作

# %% [markdown]
# ### 重新索引

# %% [raw]
# .reindex(index=None,columns=None,...)的参数

# %% [markdown]
# ![reindex.png](attachment:13a04f8e-5b14-4037-b7e7-78e0a77667b3.png)

# %%
d2.reindex(index=['d','c','b','a'],columns=['two','one'])
# Out:
#    two  one
# d    6    4
# c    7    3
# b    8    2
# a    9    1

# %%
newc = d2.columns.insert(3,'three')

# %%
d2.reindex(columns=newc,fill_value=10)
# Out:
#    one  two  three
# a    1    9     10
# b    2    8     10
# c    3    7     10
# d    4    6     10

# %% [markdown]
# ## 索引类型

# %%
d2.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
d2.columns
# Out:
# Index(['one', 'two'], dtype='object')

# %% [markdown]
# Series和DataFrame的索引类型都是Index

# %% [markdown]
# ### 索引类型的常用方法

# %% [markdown]
# ![Index_method.png](attachment:88722229-f458-4997-ad91-2601e92933ac.png)

# %% [markdown]
# ### 删除Series和DataFrame指定行或列索引

# %%
d2.drop(['b','c']) #注意多个的话要将index放在列表里
# Out:
#    one  two
# a    1    9
# d    4    6

# %%
d2.drop('d') # 单个则不用放列表
# Out:
#    one  two
# a    1    9
# b    2    8
# c    3    7

# %%
d2.drop('two',axis=1) #默认axis=0，0指的是纵轴，1指的是横轴
# Out:
#    one
# a    1
# b    2
# c    3
# d    4

# %% [markdown]
# ## 数据类型运算

# %% [markdown]
# 算术运算法则
# 算术运算根据行列索引,补齐后运算,运算默认产生浮点数。
# 补齐时缺项填充NaN(空值)，NaN与任何值相计算，还是NaN
# 维和一维、一维和零维间为广播运算
# 采用+-*/符号进行的二元运算产生新的对象

# %%
d1
# Out:
#    one  two
# a  1.0    9
# b  2.0    8
# c  3.0    7
# d  NaN    6

# %%
d3 = d2

# %%
d3.index = ['q','a','z','w']
d3
# Out:
#    one  two
# q    1    9
# a    2    8
# z    3    7
# w    4    6

# %%
d1 - d3
# Out:
#    one  two
# a -1.0  1.0
# b  NaN  NaN
# c  NaN  NaN
# d  NaN  NaN
# q  NaN  NaN
# w  NaN  NaN
# z  NaN  NaN

# %%
d1.sub(d3,axis=1,fill_value=10)
# Out:
#    one  two
# a -1.0  1.0
# b -8.0 -2.0
# c -7.0 -3.0
# d  NaN -4.0
# q  9.0  1.0
# w  6.0  4.0
# z  7.0  3.0

# %%
d1 > d2
# Out:
#      one    two
# a  False  False
# b  False  False
# c  False  False
# d  False  False

# %%
d1 == d2
# Out:
#     one   two
# a  True  True
# b  True  True
# c  True  True
# d  True  True

# %% [markdown]
# ## 数据排序

# %% [markdown]
# `.sort_index(axis=0,ascending=True)`

# %%
d2.sort_index(ascending=False) # NaN会统一放到排序末尾
# Out:
#    one  two
# d    4    6
# c    3    7
# b    2    8
# a    1    9

# %%
d2.sort_values('two',ascending=True)
# Out:
#    one  two
# d    4    6
# c    3    7
# b    2    8
# a    1    9
